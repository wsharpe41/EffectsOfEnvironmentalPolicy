# %%
import pandas as pd
import os
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# %%
# import all data that need to be processed
# Air and Climate
files_air_and_climate = os.listdir('../data/Air and Climate')
df_name_air_and_climate = []
# import csv with '_preprocessed' in name but "_imputed" not in name as pd.DataFrame
for file in files_air_and_climate:
    if '_processed' in file and '_imputed' not in file:
        globals()[file[:-4]] = pd.read_csv('../data/Air and Climate/' + file)
        df_name_air_and_climate.append(file[:-4])
        # print dataframe name
        print(file[:-4])
# Inland Water Resources
files_inland_water_resources = os.listdir('../data/Inland Water Resources')
df_name_inland_water_resources = []
# import csv with '_preprocessed' in name as pd.DataFrame
for file in files_inland_water_resources:
    if '_processed' in file and '_imputed' not in file:
        globals()[file[:-4]] = pd.read_csv('../data/Inland Water Resources/' + file)
        df_name_inland_water_resources.append(file[:-4])
        # print dataframe name
        print(file[:-4])
# Waste
files_waste = os.listdir('../data/Waste')
df_name_waste = []
# import csv with '_preprocessed' in name as pd.DataFrame
for file in files_waste:
    if '_processed' in file and '_imputed' not in file:
        globals()[file[:-4]] = pd.read_csv('../data/Waste/' + file)
        df_name_waste.append(file[:-4])
        # print dataframe name
        print(file[:-4])
# Out:
# SO2_emissions_processed
# CO2_Emissions_processed
# GHG_Emissions_processed
# CH4_Emissions_processed
# NOx_Emissions_processed
# N2O_Emissions_processed
# Net freshwater supplied by water supply industry_processed
# Freshwater abstracted_processed
# Population connected to wastewater collecting system_processed
# Wastewater treated in other treatment plants_processed
# Internal flow_processed
# Renewable freshwater resources_processed
# Fresh surface water abstracted_processed
# Wastewater treated in independent treatment facilities_processed
# Population connected to wastewater treatment_processed
# Actual evapotranspiration_processed
# Non-treated wastewater_processed
# Inflow of surface and goundwaters from neighbouring countries_processed
# Fresh groundwater abstracted_processed
# Precipitation_processed
# Renewable freshwater resources per capita_processed
# Total population supplied by water supply industry_processed
# Wastewater generated_processed
# Net freshwater supplied by water supply industry to households_processed
# Wastewater treated in urban treatment plants_processed
# Hazardous waste generated_processed
# Hazardous waste treated or disposed_processed
# Hazardous waste generated per capita_processed
# Hazardous waste landfilled_processed
# Hazardous waste recycled_processed
# Hazardous waste incinerated_processed

# %%
# convert '...' and 'NaN' into np.nan
# remove ',' in numbers
for df_name in df_name_air_and_climate:
    globals()[df_name] = globals()[df_name].replace('...', np.nan)
    globals()[df_name] = globals()[df_name].replace('NaN', np.nan)
    globals()[df_name] = globals()[df_name].replace(',', '', regex=True)
for df_name in df_name_inland_water_resources:
    globals()[df_name] = globals()[df_name].replace('...', np.nan)
    globals()[df_name] = globals()[df_name].replace('NaN', np.nan)
    globals()[df_name] = globals()[df_name].replace(',', '', regex=True)
for df_name in df_name_waste:
    globals()[df_name] = globals()[df_name].replace('...', np.nan)
    globals()[df_name] = globals()[df_name].replace('NaN', np.nan)
    globals()[df_name] = globals()[df_name].replace(',', '', regex=True)

# %%
# show all column names in jyuptyer notebook
pd.set_option('display.max_columns', None)
globals()['Hazardous waste generated per capita_processed'].head()
# Out:
#    Country ID     Country 1990         1995 1996        2000        2001
# 0        12.0     Algeria  NaN  6.400432213  NaN         NaN         NaN  \
# 1        20.0     Andorra  NaN          NaN  NaN         NaN         NaN
# 2        51.0     Armenia  NaN          NaN  NaN  124.309191  123.088320
# 3        40.0     Austria  NaN          NaN  NaN         NaN         NaN
# 4        31.0  Azerbaijan  NaN  3.472221329  NaN    3.269340    2.005178
#
#          2002        2003        2004        2005        2006        2007
# 0         NaN   10.029776         NaN         NaN         NaN    9.478113  \
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2  124.559271  114.021577  117.109443  116.167364  119.073517  123.514519
# 3         NaN         NaN  123.372406         NaN  116.104981         NaN
# 4    1.181223    3.212516    1.323607    1.502704    3.426690    1.200210
#
#          2008        2009        2010        2011        2012        2013
# 0         NaN         NaN         NaN         NaN         NaN         NaN  \
# 1         NaN         NaN         NaN         NaN         NaN   12.083694
# 2  150.352632  152.678116  151.321071  160.974708  163.261076  199.838215
# 3  159.500090         NaN  175.133523         NaN  125.140240         NaN
# 4    2.751786   14.772858   15.496448   20.300493   32.054190   21.616612
#
#          2014        2015        2016        2017  Footnotes 1990
# 0         NaN         NaN         NaN         NaN             NaN  \
# 1   26.270940   22.925134   24.883887   19.838435             NaN
# 2  197.918823  189.733505  209.618464  184.472342             NaN
# 3  147.679365         NaN  144.153297         NaN             NaN
# 4   48.037402   27.285001   64.975281   27.014877             NaN
#
#   Footnotes 1995  Footnotes 1996  Footnotes 2000  Footnotes 2001
# 0            NaN             NaN             NaN             NaN  \
# 1            NaN             NaN             NaN             NaN
# 2            NaN             NaN             NaN             NaN
# 3            NaN             NaN             NaN             NaN
# 4            NaN             NaN             NaN             NaN
#
#    Footnotes 2002  Footnotes 2003  Footnotes 2004  Footnotes 2005
# 0             NaN             1.0             NaN             NaN  \
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    Footnotes 2006 Footnotes 2007 Footnotes 2008 Footnotes 2009 Footnotes 2010
# 0             NaN            NaN            NaN            NaN            NaN  \
# 1             NaN            NaN            NaN            NaN            NaN
# 2             NaN            NaN            NaN            NaN            NaN
# 3             NaN            NaN            NaN            NaN            NaN
# 4             NaN            NaN            NaN            NaN            NaN
#
#   Footnotes 2011 Footnotes 2012 Footnotes 2013 Footnotes 2014 Footnotes 2015
# 0            NaN            NaN            NaN            NaN            NaN  \
# 1            NaN            NaN            NaN            NaN              2
# 2              3            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#   Footnotes 2016 Footnotes 2017 Basel Convention CITES
# 0            NaN            NaN             1998  1983  \
# 1              2              2             1999     …
# 2            NaN            NaN             1999  2008
# 3            NaN            NaN             1993  1982
# 4            NaN            NaN             2001  1998
#
#    Convention on Biological Diversity Convention on Migratory Species
# 0                              1995.0                            2005  \
# 1                              2015.0                             NaN
# 2                              1993.0                            2011
# 3                              1994.0                            2005
# 4                              2000.0                             NaN
#
#   Kyoto Protocol  Montreal Protocol Paris Agreement Ramsar Convention
# 0           2005             1992.0            2016              1984  \
# 1            NaN             2009.0            2017              2012
# 2           2003             1999.0            2017              1993
# 3           2002             1989.0            2016              1983
# 4           2000             1996.0            2017              2001
#
#   Rotterdam Convention Stockholm Convention
# 0                  NaN                 2006  \
# 1                  NaN                  NaN
# 2                 2003                 2003
# 3                 2002                 2002
# 4                  NaN                 2004
#
#   UN Convention on the Law of the Sea
# 0                                1996  \
# 1                                 NaN
# 2                                2002
# 3                                1995
# 4                                2016
#
#    UN Convention to Combat Desertification
# 0                                   1996.0  \
# 1                                   2002.0
# 2                                   1997.0
# 3                                   1997.0
# 4                                   1998.0
#
#    UN Framework Convention on Climate Change World Heritage Convention
# 0                                     1993.0                      1974  \
# 1                                     2011.0                      1997
# 2                                     1993.0                      1993
# 3                                     1994.0                      1992
# 4                                     1995.0                      1993
#
#    2000 Percent Change  2001 Percent Change  2002 Percent Change
# 0                  NaN                  NaN                  NaN  \
# 1                  NaN                  NaN                  NaN
# 2            -0.982124             1.195037            -8.459984
# 3                  NaN                  NaN                  NaN
# 4           -38.667201           -41.091355           171.965261
#
#    2003 Percent Change  2004 Percent Change  2005 Percent Change
# 0                  NaN                  NaN                  NaN  \
# 1                  NaN                  NaN                  NaN
# 2             2.708142            -0.804443             2.501695
# 3                  NaN                  NaN                  NaN
# 4           -58.798429            13.530997           128.034860
#
#    2006 Percent Change  2007 Percent Change  2008 Percent Change
# 0                  NaN                  NaN                  NaN  \
# 1                  NaN                  NaN                  NaN
# 2             3.729630            21.728711             1.546687
# 3                  NaN                  NaN                  NaN
# 4           -64.974641           129.275281           436.846255
#
#    2009 Percent Change  2010 Percent Change  2011 Percent Change
# 0                  NaN                  NaN                  NaN  \
# 1                  NaN                  NaN                  NaN
# 2            -0.888828             6.379573             1.420328
# 3                  NaN                  NaN                  NaN
# 4             4.898102            31.000941            57.898580
#
#    2012 Percent Change  2013 Percent Change  2014 Percent Change
# 0                  NaN                  NaN                  NaN  \
# 1                  NaN           117.408182           -12.735768
# 2            22.404078            -0.960473            -4.135695
# 3                  NaN                  NaN                  NaN
# 4           -32.562288           122.224469           -43.200506
#
#    2015 Percent Change  2016 Percent Change
# 0                  NaN                  NaN
# 1             8.544126           -20.275978
# 2            10.480468           -11.996139
# 3                  NaN                  NaN
# 4           138.135525           -58.422839

# %%
# # split dataframes into two parts: columns need to be interpolated and columns don't need to be interpolated
# # convert '...' and 'NaN' into np.nan
# # Air and Climate
# df_name_air_and_climate_need_interpolation = []
# df_name_air_and_climate_no_need_interpolation = []
# for df_name in df_name_air_and_climate:
#     globals()[df_name] = globals()[df_name].replace('...', None)
#     globals()[df_name] = globals()[df_name].replace('NaN', None)
#     # split dataframes into two parts: columns need to be interpolated and columns don't need to be interpolated
#     globals()[df_name + '_need_interpolation'] = globals()[df_name].iloc[:, 2:31]
#     globals()[df_name + '_no_need_interpolation'] = globals()[df_name].iloc[:, 0:2] + globals()[df_name].iloc[:, 31:]
#     # save dataframe names
#     df_name_air_and_climate_need_interpolation.append(df_name + '_need_interpolation')
#     df_name_air_and_climate_no_need_interpolation.append(df_name + '_no_need_interpolation')

# %%
# df_name = 'CO2_Emissions_processed_need_interpolation'
# globals()[df_name].columns = pd.to_datetime(globals()[df_name].columns, format='%Y').year
# # globals()[df_name].dropna(thresh=2, axis=0)
# globals()[df_name+'_interpolated'] = globals()[df_name].dropna(thresh=3, axis=0).interpolate(method='time', order=2, axis=1, limit_direction='both', limit=27)
# globals()[df_name+'_interpolated'].columns = pd.to_datetime(globals()[df_name+'_interpolated'].columns, format='%Y').year
# # update the original dataframe
# globals()[df_name].update(globals()[df_name+'_interpolated'], overwrite=True)
# globals()[df_name]

# %%
# Impute missing values
# Air and Climate
for df_name in df_name_air_and_climate:
    for row in range(globals()[df_name].shape[0]):
        # if the row has less than 3 non-NaN values or all values are non-NaN, skip
        if globals()[df_name].iloc[row, 2:31].notnull().sum() < 3 or globals()[df_name].iloc[row, 2:31].isnull().sum() == 0:
            continue
        else:
            # fit an logistic regression model to predict the missing values
            # select data that is not NaN in the row as training data
            X_train = globals()[df_name].iloc[row, 2:31][~globals()[df_name].iloc[row, 2:31].isnull()].index.values.astype('int64').reshape(-1, 1)
            y_train = globals()[df_name].iloc[row, 2:31][~globals()[df_name].iloc[row, 2:31].isnull()].values.astype('float64')
            # fit a Polynomial Regression model
            poly_reg = PolynomialFeatures(degree=2)
            X_poly = poly_reg.fit_transform(X_train)
            lin_reg = LinearRegression()
            lin_reg.fit(X_poly, y_train)
            # predict the missing values
            X_test = globals()[df_name].iloc[row, 2:31][globals()[df_name].iloc[row, 2:31].isnull()].index.values.astype('int64').reshape(-1, 1)
            y_pred = lin_reg.predict(poly_reg.fit_transform(X_test))
            # update the original dataframe based on X_test and y_pred using DataFrame.at
            for i in range(len(X_test)):
                globals()[df_name].at[row, str(X_test[i][0])] = y_pred[i]
    # save the imputed dataframe
    globals()[df_name].to_csv('../data/Air and Climate/' + df_name + '_imputed.csv', index=False)
    print(df_name + ' imputed')
# Out:
# CO2_Emissions_processed imputed
# NOx_Emissions_processed imputed
# GHG_Emissions_processed imputed
# SO2_emissions_processed imputed
# CH4_Emissions_processed imputed
# N2O_Emissions_processed imputed

# %%
# Inland Water Resources
for df_name in df_name_inland_water_resources:
    for row in range(globals()[df_name].shape[0]):
        # if the row has less than 3 non-NaN values or all values are non-NaN, skip
        if globals()[df_name].iloc[row, 2:26].notnull().sum() < 3 or globals()[df_name].iloc[row, 2:26].isnull().sum() == 0:
            # print(df_name + ' row ' + str(row) + ' skipped')
            continue
        else:
            # fit an logistic regression model to predict the missing values
            # select data that is not NaN in the row as training data
            X_train = globals()[df_name].iloc[row, 2:26][~globals()[df_name].iloc[row, 2:26].isnull()].index.values.astype('int64').reshape(-1, 1)
            y_train = globals()[df_name].iloc[row, 2:26][~globals()[df_name].iloc[row, 2:26].isnull()].values.astype('float64')
            # fit a Polynomial Regression model
            poly_reg = PolynomialFeatures(degree=2)
            X_poly = poly_reg.fit_transform(X_train)
            lin_reg = LinearRegression()
            lin_reg.fit(X_poly, y_train)
            # predict the missing values
            X_test = globals()[df_name].iloc[row, 2:26][globals()[df_name].iloc[row, 2:26].isnull()].index.values.astype('int64').reshape(-1, 1)
            y_pred = lin_reg.predict(poly_reg.fit_transform(X_test))
            # update the original dataframe based on X_test and y_pred using DataFrame.at
            for i in range(len(X_test)):
                globals()[df_name].at[row, str(X_test[i][0])] = y_pred[i]
            # print(df_name + ' row ' + str(row) + ' imputed')
    # save the imputed dataframe
    globals()[df_name].to_csv('../data/Inland Water Resources/' + df_name + '_imputed.csv', index=False)
    print(df_name + ' imputed')
# Out:
# Wastewater generated_processed imputed
# Actual evapotranspiration_processed imputed
# Population connected to wastewater treatment_processed imputed
# Freshwater abstracted_processed imputed
# Total population supplied by water supply industry_processed imputed
# Inflow of surface and goundwaters from neighbouring countries_processed imputed
# Net freshwater supplied by water supply industry to households_processed imputed
# Internal flow_processed imputed
# Wastewater treated in other treatment plants_processed imputed
# Fresh surface water abstracted_processed imputed
# Precipitation_processed imputed
# Non-treated wastewater_processed imputed
# Wastewater treated in independent treatment facilities_processed imputed
# Renewable freshwater resources_processed imputed
# Wastewater treated in urban treatment plants_processed imputed
# Net freshwater supplied by water supply industry_processed imputed
# Renewable freshwater resources per capita_processed imputed
# Population connected to wastewater collecting system_processed imputed
# Fresh groundwater abstracted_processed imputed

# %%
df_name = "Hazardous waste generated per capita_processed"
globals()[df_name].iloc[:,58:]
# Out:
#     2000 Percent Change  2001 Percent Change  2002 Percent Change
# 0                   NaN                  NaN                  NaN  \
# 1                   NaN                  NaN                  NaN
# 2             -0.982124             1.195037            -8.459984
# 3                   NaN                  NaN                  NaN
# 4            -38.667201           -41.091355           171.965261
# ..                  ...                  ...                  ...
# 94                  NaN                  NaN                  NaN
# 95                  NaN                  NaN                  NaN
# 96                  NaN                  NaN                  NaN
# 97                  NaN                  NaN                  NaN
# 98                  NaN                  NaN                  NaN
#
#     2003 Percent Change  2004 Percent Change  2005 Percent Change
# 0                   NaN                  NaN                  NaN  \
# 1                   NaN                  NaN                  NaN
# 2              2.708142            -0.804443             2.501695
# 3                   NaN                  NaN                  NaN
# 4            -58.798429            13.530997           128.034860
# ..                  ...                  ...                  ...
# 94                  NaN                  NaN                  NaN
# 95                  NaN                  NaN                  NaN
# 96                  NaN                  NaN                  NaN
# 97                  NaN                  NaN                  NaN
# 98                  NaN                  NaN                  NaN
#
#     2006 Percent Change  2007 Percent Change  2008 Percent Change
# 0                   NaN                  NaN                  NaN  \
# 1                   NaN                  NaN                  NaN
# 2              3.729630            21.728711             1.546687
# 3                   NaN                  NaN                  NaN
# 4            -64.974641           129.275281           436.846255
# ..                  ...                  ...                  ...
# 94                  NaN                  NaN                  NaN
# 95                  NaN                  NaN                  NaN
# 96                  NaN                  NaN                  NaN
# 97                  NaN                  NaN                  NaN
# 98                  NaN                  NaN                  NaN
#
#     2009 Percent Change  2010 Percent Change  2011 Percent Change
# 0                   NaN                  NaN                  NaN  \
# 1                   NaN                  NaN                  NaN
# 2             -0.888828             6.379573             1.420328
# 3                   NaN                  NaN                  NaN
# 4              4.898102            31.000941            57.898580
# ..                  ...                  ...                  ...
# 94                  NaN                  NaN                  NaN
# 95                  NaN                  NaN                  NaN
# 96                  NaN                  NaN                  NaN
# 97                  NaN                  NaN                  NaN
# 98                  NaN                  NaN                  NaN
#
#     2012 Percent Change  2013 Percent Change  2014 Percent Change
# 0                   NaN                  NaN                  NaN  \
# 1                   NaN           117.408182           -12.735768
# 2             22.404078            -0.960473            -4.135695
# 3                   NaN                  NaN                  NaN
# 4            -32.562288           122.224469           -43.200506
# ..                  ...                  ...                  ...
# 94                  NaN                  NaN             0.712055
# 95                  NaN                  NaN                  NaN
# 96                  NaN                  NaN                  NaN
# 97                  NaN                  NaN                  NaN
# 98                  NaN                  NaN                  NaN
#
#     2015 Percent Change  2016 Percent Change
# 0                   NaN                  NaN
# 1              8.544126           -20.275978
# 2             10.480468           -11.996139
# 3                   NaN                  NaN
# 4            138.135525           -58.422839
# ..                  ...                  ...
# 94             7.002280            93.707992
# 95                  NaN                  NaN
# 96                  NaN                  NaN
# 97                  NaN                  NaN
# 98                  NaN                  NaN
#
# [99 rows x 17 columns]

# %%
for df_name in df_name_waste:
    print(df_name)
    if df_name == "Hazardous waste generated_processed":
        print(globals()[df_name].iloc[:, 64:].columns)
# Out:
# Hazardous waste generated_processed
# Index(['World Heritage Convention', '2000 Percent Change',
#        '2001 Percent Change', '2002 Percent Change', '2003 Percent Change',
#        '2004 Percent Change', '2005 Percent Change', '2006 Percent Change',
#        '2007 Percent Change', '2008 Percent Change', '2009 Percent Change',
#        '2010 Percent Change', '2011 Percent Change', '2012 Percent Change',
#        '2013 Percent Change', '2014 Percent Change', '2015 Percent Change',
#        '2016 Percent Change'],
#       dtype='object')
# Hazardous waste treated or disposed_processed
# Hazardous waste generated per capita_processed
# Hazardous waste landfilled_processed
# Hazardous waste recycled_processed
# Hazardous waste incinerated_processed

# %%
# Waste
for df_name in df_name_waste:
    i_col = 64
    if df_name == "Hazardous waste generated per capita_processed":
        i_col = 58
    elif df_name == "Hazardous waste generated_processed":
        i_col = 65
    for row in range(globals()[df_name].shape[0]):
        # if the row has less than 3 non-NaN values or all values are non-NaN, skip
        if globals()[df_name].iloc[row, i_col:].notnull().sum() < 3 or globals()[df_name].iloc[row, i_col:].isnull().sum() == 0:
            continue
        else:
            # fit an logistic regression model to predict the missing values
            # select data that is not NaN in the row as training data
            X_train = globals()[df_name].iloc[row,i_col:][~globals()[df_name].iloc[row, i_col:].isnull()].index.values.astype('int64').reshape(-1, 1)
            y_train = globals()[df_name].iloc[row, i_col:][~globals()[df_name].iloc[row, i_col:].isnull()].values.astype('float64')
            # fit a Polynomial Regression model
            poly_reg = PolynomialFeatures(degree=2)
            X_poly = poly_reg.fit_transform(X_train)
            lin_reg = LinearRegression()
            lin_reg.fit(X_poly, y_train)
            # predict the missing values
            X_test = globals()[df_name].iloc[row, i_col:][globals()[df_name].iloc[row, i_col:].isnull()].index.values.astype('int64').reshape(-1, 1)
            y_pred = lin_reg.predict(poly_reg.fit_transform(X_test))
            # update the original dataframe based on X_test and y_pred using DataFrame.at
            for i in range(len(X_test)):
                globals()[df_name].at[row, str(X_test[i][0])] = y_pred[i]
    # save the imputed dataframe
    globals()[df_name].to_csv('../data/Waste/' + df_name + '_imputed.csv', index=False)
    print(df_name + ' imputed')
# Out:
# [['2013 Percent Change']
#  ['2014 Percent Change']
#  ['2015 Percent Change']
#  ['2016 Percent Change']]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 20
#      18 # fit a Polynomial Regression model
#      19 poly_reg = PolynomialFeatures(degree=2)
# ---> 20 X_poly = poly_reg.fit_transform(X_train)
#      21 lin_reg = LinearRegression()
#      22 lin_reg.fit(X_poly, y_train)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File ~/.local/lib/python3.10/site-packages/sklearn/base.py:878, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     874 # non-optimized default implementation; override when a better
#     875 # method is possible for a given clustering algorithm
#     876 if y is None:
#     877     # fit method of arity 1 (unsupervised transformation)
# --> 878     return self.fit(X, **fit_params).transform(X)
#     879 else:
#     880     # fit method of arity 2 (supervised transformation)
#     881     return self.fit(X, y, **fit_params).transform(X)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/preprocessing/_polynomial.py:252, in PolynomialFeatures.fit(self, X, y)
#     235 """
#     236 Compute number of output features.
#     237
#    (...)
#     249     Fitted transformer.
#     250 """
#     251 self._validate_params()
# --> 252 _, n_features = self._validate_data(X, accept_sparse=True).shape
#     254 if isinstance(self.degree, Integral):
#     255     if self.degree == 0 and not self.include_bias:
#
# File ~/.local/lib/python3.10/site-packages/sklearn/base.py:565, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     563     raise ValueError("Validation should be done on X, y or both.")
#     564 elif not no_val_X and no_val_y:
# --> 565     X = check_array(X, input_name="X", **check_params)
#     566     out = X
#     567 elif no_val_X and not no_val_y:
#
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:879, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     877         array = xp.astype(array, dtype, copy=False)
#     878     else:
# --> 879         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     880 except ComplexWarning as complex_warning:
#     881     raise ValueError(
#     882         "Complex data not supported\n{}\n".format(array)
#     883     ) from complex_warning
#
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/_array_api.py:185, in _asarray_with_order(array, dtype, order, copy, xp)
#     182     xp, _ = get_namespace(array)
#     183 if xp.__name__ in {"numpy", "numpy.array_api"}:
#     184     # Use NumPy API to support order
# --> 185     array = numpy.asarray(array, order=order, dtype=dtype)
#     186     return xp.asarray(array, copy=copy)
#     187 else:
#
# ValueError: could not convert string to float: '2013 Percent Change'
